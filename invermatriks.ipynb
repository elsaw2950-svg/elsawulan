# %% [markdown]
# ## Matriks Awal dan Invers Matriks \( A \)
#
# Matriks \( A \) adalah:
#
# \[
# A = \begin{bmatrix}
# 1 & 1 & 1 & 1 \\
# 2 & -1 & 1 & -1 \\
# 1 & 2 & -1 & 1 \\
# 3 & -1 & 2 & 1
# \end{bmatrix}
# \]
#
# Invers matriks \( A \) adalah:
#
# \[
# A^{-1} = \begin{bmatrix}
# 0.25 & 0.25 & -0.25 & 0.25 \\
# 0.0833 & -0.4167 & 0.4167 & -0.0833 \\
# -0.0833 & 0.4167 & 0.0833 & 0.4167 \\
# -0.25 & 0.25 & 0.25 & -0.25
# \end{bmatrix}
# \]
